# %%
# ETF_Cache.ipynb

import time
import pandas as pd
from ETF_Tickers import ETF_Ticker_List
from stock_cache import (
    fetch_stock_data_bulk,
    stock_df_from_cache,
    method_df_from_cache,
    save_cache_parquet,
    load_cache_parquet_if_fresh
)
from main_table import build_quick_table

# -----------------------------
# CONFIG
# -----------------------------
ETF_PATH = r"iShares-Core-MSCI-World-UCITS-ETF_fund.csv"
CACHE_PATH = "etf_cache.parquet"
TOP_N = None          # None = all tickers
MAX_AGE_HOURS = 24    # freshness for "quick load"
MAX_WORKERS = 4       # lower concurrency to reduce rate limits
BATCH = 100           # fetch in chunks; 150–250 is reasonable
PAUSE_SEC = 12         # pause between batches to be polite
# -----------------------------


def refresh_cache(tickers, path=CACHE_PATH):
    """
    Load existing cache (even if old), fetch missing tickers,
    save merged cache, and return it.
    """
    existing_cache = load_cache_parquet_if_fresh(path, max_age_hours=1e9) or {}
    missing = [t for t in tickers if t not in existing_cache]

    if not missing:
        print("✅ No missing tickers — cache is complete.")
        return existing_cache

    print(f"Need to fetch {len(missing)} tickers.")
    for i in range(0, len(missing), BATCH):
        batch = missing[i:i+BATCH]
        print(f"Fetching batch {i//BATCH + 1} / {((len(missing)-1)//BATCH)+1} — {len(batch)} tickers...")
        new_data = fetch_stock_data_bulk(batch, max_workers=MAX_WORKERS)
        # keep successful only
        existing_cache.update({k: v for k, v in new_data.items() if v})
        save_cache_parquet(existing_cache, path)
        print(f"Saved cache after {i+len(batch)} tickers.")
        time.sleep(PAUSE_SEC)

    return existing_cache


# -----------------------------
# MAIN EXECUTION
# -----------------------------
tickers = ETF_Ticker_List(ETF_PATH, top_n=TOP_N)
print(f"Loaded {len(tickers)} tickers from ETF list.")

cache = refresh_cache(tickers)

# Quick preview
df_metrics = stock_df_from_cache(cache)
df_methods = method_df_from_cache(cache)

print("\n=== Metrics preview ===")
print(df_metrics.head())

print("\n=== Methods preview ===")
print(df_methods.head())

quick_df = build_quick_table(cache)
print("\n=== Quick View Table ===")
print(quick_df.head())
quick_df.to_csv("quick_view.csv", index=False)


# Optional: Save preview to CSV for quick reference
df_metrics.to_csv("metrics_preview.csv", index=False)
df_methods.to_csv("methods_preview.csv", index=False)

print("\n💾 Cache updated & preview saved.")
# Out:
# Loaded 1345 tickers from ETF list.
# ✅ No missing tickers — cache is complete.
#
# === Metrics preview ===
#   Ticker          Short Name   Price  Pe Ratio  Peg Ratio  Eps Ttm  \
# 0   TSLA         Tesla, Inc.  329.65    196.22       6.07     1.68
# 1   AAPL          Apple Inc.  229.35     34.75       2.00     6.60
# 2   AMZN    Amazon.com, Inc.  222.69     33.95       2.64     6.56
# 3  GOOGL       Alphabet Inc.  201.42     21.50       1.46     9.37
# 4   NVDA  NVIDIA Corporation  182.70     59.13       1.75     3.09
#
#    Total Revenue  Growth  3-4 Year Sales Growth   Cagr  ...  Dividend Yield%  \
# 0   9.272000e+10   32.30                  81.50  18.00  ...             0.00
# 1   4.086250e+11   17.39                   6.89   1.87  ...             0.00
# 2   6.700380e+11   12.86                  35.79   8.86  ...             0.00
# 3   3.713990e+11   14.72                  35.86   8.88  ...             0.01
# 4   1.485150e+11   33.74                 384.87  55.00  ...             0.00
#
#    Earnings Growth   Roe   Roa  Debt To Equity  Pb Ratio  Free Cash Flow  \
# 0            -0.16  0.08  0.03            0.17     13.75    1.339625e+09
# 1             0.09  1.50  0.25            1.54     51.76    9.487375e+10
# 2             0.35  0.25  0.08            0.48      7.11    3.102400e+10
# 3             0.19  0.35  0.17            0.11      6.72    4.978650e+10
# 4             0.26  1.15  0.53            0.12     53.14    5.544300e+10
#
#      Market Cap  Rev Growth                  Sector
# 0  1.063270e+12       -0.12       Consumer Cyclical
# 1  3.403646e+12        0.10              Technology
# 2  2.374966e+12        0.13       Consumer Cyclical
# 3  2.440203e+12        0.14  Communication Services
# 4  4.455614e+12        0.69              Technology
#
# [5 rows x 25 columns]
#
# === Methods preview ===
#   Ticker                Name  Peter Lynch  Warren Buffett  Philip Fisher  \
# 0   TSLA         Tesla, Inc.         0.33              20              0
# 1   AAPL          Apple Inc.         1.00              50             30
# 2   AMZN    Amazon.com, Inc.         0.76              70            100
# 3  GOOGL       Alphabet Inc.         1.37             100            100
# 4   NVDA  NVIDIA Corporation         1.14              70            100
#
#    Magic Formula  Benjamin Graham  Seth Klarman  Personal Model Final Score
# 0              0               20            66            37.5       20.5%
# 1             50               40            33            75.0      46.86%
# 2             50               40            66            87.5      61.93%
# 3             50               60            66           100.0      75.14%
# 4             50               60            66            87.5      69.07%
# HTTP Error 404:
# HTTP Error 404:
#
# 13 Failed downloads:
# ['27.HK', '388.HK', '288.HK', '11.HK', '1CO', '1.HK', '3.HK', '19.HK', '16.HK', '2299955D.TO', '2.HK', '12.HK', '4.HK']: YFPricesMissingError('possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")')
# $1.HK: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $11.HK: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $12.HK: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $16.HK: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $19.HK: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $1CO: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $2.HK: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $2299955D.TO: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $27.HK: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $288.HK: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $3.HK: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $388.HK: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $4.HK: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
#
# 3 Failed downloads:
# ['6.HK', '66.HK', '669.HK']: YFPricesMissingError('possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")')
# $6.HK: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $66.HK: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $669.HK: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
#
# 2 Failed downloads:
# ['823.HK', '83.HK']: YFPricesMissingError('possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")')
# $823.HK: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $83.HK: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
#
# 6 Failed downloads:
# ['ABN', 'AD', 'ACS']: YFPricesMissingError('possibly delisted; no price data found  (period=1y)')
# ['ADYEN', 'ADS', 'A5G']: YFPricesMissingError('possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")')
# $A5G: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $ABN: possibly delisted; no price data found  (period=1y)
# $ACS: possibly delisted; no price data found  (period=1y)
# $AD: possibly delisted; no price data found  (period=1y)
# $ADS: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $ADYEN: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
#
# 7 Failed downloads:
# ['AMUN', 'ANA']: YFPricesMissingError('possibly delisted; no price data found  (period=1y)')
# ['AKZA', 'AENA', 'AGN', 'ALO', 'AKE']: YFPricesMissingError('possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")')
# $AENA: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $AGN: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $AKE: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $AKZA: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $ALO: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $AMUN: possibly delisted; no price data found  (period=1y)
# $ANA: possibly delisted; no price data found  (period=1y)
#
# 13 Failed downloads:
# ['BEI', 'BESI', 'AUD.AX', 'BIM']: YFPricesMissingError('possibly delisted; no price data found  (period=1y)')
# ['BAS', 'AV..L', 'ASRNL', 'BAMI', 'BFB', 'BIRG', 'BAYN', 'BA..L']: YFPricesMissingError('possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")')
# ['AVB']: Timeout('Failed to perform, curl: (28) Connection timed out after 10001 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# $ASRNL: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $AUD.AX: possibly delisted; no price data found  (period=1y)
# $AV..L: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $BA..L: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $BAMI: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $BAS: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $BAYN: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $BEI: possibly delisted; no price data found  (period=1y)
# $BESI: possibly delisted; no price data found  (period=1y)
# $BFB: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $BIM: possibly delisted; no price data found  (period=1y)
# $BIRG: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
#
# 14 Failed downloads:
# ['BPE', 'BNP', 'BOL', 'BMW', 'CABK', 'BVI']: YFPricesMissingError('possibly delisted; no price data found  (period=1y)')
# ['BMW3', 'CCL.B.TO', 'BRKB', 'CAD.TO', 'CBK', 'BP..L', 'BZFUT', 'BT.A.L']: YFPricesMissingError('possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")')
# $BMW: possibly delisted; no price data found  (period=1y)
# $BMW3: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $BNP: possibly delisted; no price data found  (period=1y)
# $BOL: possibly delisted; no price data found  (period=1y)
# $BP..L: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $BPE: possibly delisted; no price data found  (period=1y)
# $BRKB: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $BT.A.L: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $BVI: possibly delisted; no price data found  (period=1y)
# $BZFUT: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $CABK: possibly delisted; no price data found  (period=1y)
# $CAD.TO: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $CBK: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $CCL.B.TO: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
#
# 6 Failed downloads:
# ['CPR', 'COV', 'CLNX']: YFPricesMissingError('possibly delisted; no price data found  (period=1y)')
# ['CTC.A.TO', 'CS', 'CHF.SW']: YFPricesMissingError('possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")')
# $CHF.SW: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $CLNX: possibly delisted; no price data found  (period=1y)
# $COV: possibly delisted; no price data found  (period=1y)
# $CPR: possibly delisted; no price data found  (period=1y)
# $CS: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $CTC.A.TO: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
#
# 8 Failed downloads:
# ['DKK.CO', 'DHER', 'DSFIR', 'DB1']: YFPricesMissingError('possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")')
# ['DIE', 'DHL', 'DBK', 'CVC']: YFPricesMissingError('possibly delisted; no price data found  (period=1y)')
# $CVC: possibly delisted; no price data found  (period=1y)
# $DB1: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $DBK: possibly delisted; no price data found  (period=1y)
# $DHER: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $DHL: possibly delisted; no price data found  (period=1y)
# $DIE: possibly delisted; no price data found  (period=1y)
# $DKK.CO: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $DSFIR: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
#
# 15 Failed downloads:
# ['EN', 'ENI', 'ELI', 'EVD', 'EDP', 'ELE']: YFPricesMissingError('possibly delisted; no price data found  (period=1y)')
# ['ENEL', 'ENGI', 'EVK', 'ESU5', 'EDPR', 'EOAN', 'ELISA', 'ERF', 'EMP.A.TO']: YFPricesMissingError('possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")')
# $EDP: possibly delisted; no price data found  (period=1y)
# $EDPR: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $ELE: possibly delisted; no price data found  (period=1y)
# $ELI: possibly delisted; no price data found  (period=1y)
# $ELISA: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $EMP.A.TO: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $EN: possibly delisted; no price data found  (period=1y)
# $ENEL: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $ENGI: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $ENI: possibly delisted; no price data found  (period=1y)
# $EOAN: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $ERF: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $ESU5: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $EVD: possibly delisted; no price data found  (period=1y)
# $EVK: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
#
# 13 Failed downloads:
# ['FGR', 'FME', 'EXO', 'FRE']: YFPricesMissingError('possibly delisted; no price data found  (period=1y)')
# ['G24', 'GFC', 'GBP.L', 'FDJU', 'G1A', 'GALP', 'GBLB', 'GET', 'FORTUM']: YFPricesMissingError('possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")')
# $EXO: possibly delisted; no price data found  (period=1y)
# $FDJU: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $FGR: possibly delisted; no price data found  (period=1y)
# $FME: possibly delisted; no price data found  (period=1y)
# $FORTUM: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $FRE: possibly delisted; no price data found  (period=1y)
# $G1A: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $G24: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $GALP: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $GBLB: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $GBP.L: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $GET: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $GFC: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
#
# 9 Failed downloads:
# ['HEIO', 'GIB.A.TO', 'HEIA', 'HNR1', 'H78', 'HEN3']: YFPricesMissingError('possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")')
# ['HEN', 'HKD.HK', 'HO']: YFPricesMissingError('possibly delisted; no price data found  (period=1y)')
# $GIB.A.TO: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $H78: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $HEIA: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $HEIO: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $HEN: possibly delisted; no price data found  (period=1y)
# $HEN3: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $HKD.HK: possibly delisted; no price data found  (period=1y)
# $HNR1: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $HO: possibly delisted; no price data found  (period=1y)
#
# 13 Failed downloads:
# ['ITX', 'IPN', 'IBE', 'INGA', 'INW', 'IFX']: YFPricesMissingError('possibly delisted; no price data found  (period=1y)')
# ['ICSUAGD', 'J36', 'JDEP', 'IMCD', 'INPST', 'ILS.TA', 'JD..L']: YFPricesMissingError('possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")')
# $IBE: possibly delisted; no price data found  (period=1y)
# $ICSUAGD: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $IFX: possibly delisted; no price data found  (period=1y)
# $ILS.TA: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $IMCD: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $INGA: possibly delisted; no price data found  (period=1y)
# $INPST: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $INW: possibly delisted; no price data found  (period=1y)
# $IPN: possibly delisted; no price data found  (period=1y)
# $ITX: possibly delisted; no price data found  (period=1y)
# $J36: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $JD..L: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $JDEP: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
#
# 14 Failed downloads:
# ['KER', 'KBC', 'KPN', 'KRZ', 'LR', 'LHA', 'LDO', 'KBX', 'KRX']: YFPricesMissingError('possibly delisted; no price data found  (period=1y)')
# ['KNEBV', 'LOTB', 'KESKOB', 'JMT', 'JPY.T']: YFPricesMissingError('possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")')
# $JMT: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $JPY.T: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $KBC: possibly delisted; no price data found  (period=1y)
# $KBX: possibly delisted; no price data found  (period=1y)
# $KER: possibly delisted; no price data found  (period=1y)
# $KESKOB: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $KNEBV: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $KPN: possibly delisted; no price data found  (period=1y)
# $KRX: possibly delisted; no price data found  (period=1y)
# $KRZ: possibly delisted; no price data found  (period=1y)
# $LDO: possibly delisted; no price data found  (period=1y)
# $LHA: possibly delisted; no price data found  (period=1y)
# $LOTB: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $LR: possibly delisted; no price data found  (period=1y)
#
# 3 Failed downloads:
# ['METSO', 'MONC', 'ML']: YFPricesMissingError('possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")')
# $METSO: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $ML: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $MONC: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
#
# 7 Failed downloads:
# ['NOK.OL', 'OMV']: YFPricesMissingError('possibly delisted; no price data found  (period=1y)')
# ['NZD.NZ', 'NESTE', 'NOKIA', 'MUV2', 'NG..L']: YFPricesMissingError('possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")')
# $MUV2: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $NESTE: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $NG..L: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $NOK.OL: possibly delisted; no price data found  (period=1y)
# $NOKIA: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $NZD.NZ: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $OMV: possibly delisted; no price data found  (period=1y)
#
# 7 Failed downloads:
# ['PRY', 'PRX']: YFPricesMissingError('possibly delisted; no price data found  (period=1y)')
# ['PUB', 'ORNBV', 'PAH3', 'PHIA', 'P911']: YFPricesMissingError('possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")')
# $ORNBV: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $P911: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $PAH3: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $PHIA: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $PRX: possibly delisted; no price data found  (period=1y)
# $PRY: possibly delisted; no price data found  (period=1y)
# $PUB: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
#
# 15 Failed downloads:
# ['RNO', 'RHM', 'REP', 'RI', 'RED', 'SAB', 'RYA', 'QIA', 'SAF', 'RWE', 'RMS']: YFPricesMissingError('possibly delisted; no price data found  (period=1y)')
# ['RCI.B.TO', 'QBR.B.TO', 'RR..L', 'SAMPO']: YFPricesMissingError('possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")')
# $QBR.B.TO: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $QIA: possibly delisted; no price data found  (period=1y)
# $RCI.B.TO: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $RED: possibly delisted; no price data found  (period=1y)
# $REP: possibly delisted; no price data found  (period=1y)
# $RHM: possibly delisted; no price data found  (period=1y)
# $RI: possibly delisted; no price data found  (period=1y)
# $RMS: possibly delisted; no price data found  (period=1y)
# $RNO: possibly delisted; no price data found  (period=1y)
# $RR..L: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $RWE: possibly delisted; no price data found  (period=1y)
# $RYA: possibly delisted; no price data found  (period=1y)
# $SAB: possibly delisted; no price data found  (period=1y)
# $SAF: possibly delisted; no price data found  (period=1y)
# $SAMPO: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
#
# 6 Failed downloads:
# ['SGD.SI', 'SGO', 'SHL', 'SIE']: YFPricesMissingError('possibly delisted; no price data found  (period=1y)')
# ['SEK.ST', 'SN..L']: YFPricesMissingError('possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")')
# $SEK.ST: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $SGD.SI: possibly delisted; no price data found  (period=1y)
# $SGO: possibly delisted; no price data found  (period=1y)
# $SHL: possibly delisted; no price data found  (period=1y)
# $SIE: possibly delisted; no price data found  (period=1y)
# $SN..L: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
#
# 9 Failed downloads:
# ['SRT3', 'STLAM', 'SY1', 'SYENS', 'STMPA', 'TECK.B.TO', 'STERV']: YFPricesMissingError('possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")')
# ['TEP', 'TIT']: YFPricesMissingError('possibly delisted; no price data found  (period=1y)')
# $SRT3: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $STERV: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $STLAM: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $STMPA: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $SY1: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $SYENS: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $TECK.B.TO: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $TEP: possibly delisted; no price data found  (period=1y)
# $TIT: possibly delisted; no price data found  (period=1y)
#
# 11 Failed downloads:
# ['UCG', 'UNI', 'URW', 'UPM']: YFPricesMissingError('possibly delisted; no price data found  (period=1y)')
# ['UMG', 'UHALB', 'UU..L', 'VER', 'TPU5.T', 'VGU5', 'VIE']: YFPricesMissingError('possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")')
# $TPU5.T: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $UCG: possibly delisted; no price data found  (period=1y)
# $UHALB: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $UMG: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $UNI: possibly delisted; no price data found  (period=1y)
# $UPM: possibly delisted; no price data found  (period=1y)
# $URW: possibly delisted; no price data found  (period=1y)
# $UU..L: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $VER: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $VGU5: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $VIE: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
#
# 6 Failed downloads:
# ['WKL', 'VNA']: YFPricesMissingError('possibly delisted; no price data found  (period=1y)')
# ['WRT1V', 'Z-U5.L', 'VOW3']: YFPricesMissingError('possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")')
# ['WTW']: Timeout('Failed to perform, curl: (28) Connection timed out after 10002 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# $VNA: possibly delisted; no price data found  (period=1y)
# $VOW3: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $WKL: possibly delisted; no price data found  (period=1y)
# $WRT1V: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $Z-U5.L: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
#
# 2 Failed downloads:
# ['ZAL']: YFPricesMissingError('possibly delisted; no price data found  (period=1y)')
# ['NAN.TO']: YFPricesMissingError('possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")')
# $ZAL: possibly delisted; no price data found  (period=1y)
# $NAN.TO: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# === Quick View Table ===
#   Ticker                Name                  Sector     P/E    P/B   PEG  \
# 0   TSLA         Tesla, Inc.       Consumer Cyclical  196.22  13.75  6.07
# 1   AAPL          Apple Inc.              Technology   34.75  51.76  2.00
# 2   AMZN    Amazon.com, Inc.       Consumer Cyclical   33.95   7.11  2.64
# 3  GOOGL       Alphabet Inc.  Communication Services   21.50   6.72  1.46
# 4   NVDA  NVIDIA Corporation              Technology   59.13  53.14  1.75
#
#     D/E  ROIC  Dividend Yield %   1M %   1Y %  Peter Lynch  Personal Model
# 0  0.17  0.10              0.00  10.69  64.82         0.33            37.5
# 1  1.54  0.78              0.00   9.21   6.06         1.00            75.0
# 2  0.48  0.22              0.00   1.52  33.40         0.76            87.5
# 3  0.11  0.36              0.01  15.52  23.06         1.37           100.0
# 4  0.12  0.96              0.00  14.19  74.42         1.14            87.5
#
# 💾 Cache updated & preview saved.
