# %%
from ETF_Tickers import ETF_Ticker_List
from Stocks import stock_df, method_df

tickers = ETF_Ticker_List()

def basic(n):
    basic = stock_df(tickers[:n])
    return basic
def scores(n):
    scores = method_df(tickers[:n])
    return scores

basic(100)
#scores
# Out:
# HTTP Error 404:
#                          Short Name Ticker   Price  Pe Ratio  Peg Ratio  \
# 0                NVIDIA Corporation   NVDA  182.70     59.13       1.75
# 1             Microsoft Corporation   MSFT  522.04     38.24       2.34
# 2                        Apple Inc.   AAPL  229.35     34.75       2.00
# 3                  Amazon.com, Inc.   AMZN  222.69     33.95       2.64
# 4              Meta Platforms, Inc.   META  769.30     27.89       2.40
# ..                              ...    ...     ...       ...        ...
# 95              Suncor Energy  Inc.     SU   39.22     11.88        NaN
# 96  Capital One Financial Corporati    COF  208.23    594.94       0.91
# 97        Union Pacific Corporation    UNP  222.24     19.31       2.71
# 98  Banco Santander, S.A. Sponsored    SAN    9.31      9.80       3.22
# 99              Stryker Corporation    SYK  377.58     49.88       2.15
#
#     Eps Ttm  Total Revenue  Growth  3-4 Year Sales Growth   Cagr  ...  \
# ...
